# %% [markdown]
# ## Artificial datasets and complexity at the instance level

# %%
# Load packages
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
root_path = os.getcwd()
os.chdir(root_path+'/datasets')

# %%
dataset1 = pd.read_csv('Dataset1.csv')
dataset2 = pd.read_csv('Dataset2.csv')
dataset3 = pd.read_csv('Dataset3.csv')
dataset4 = pd.read_csv('Dataset4.csv')
dataset5 = pd.read_csv('Dataset5.csv')
dataset6 = pd.read_csv('Dataset6.csv')
dataset7 = pd.read_csv('Dataset7.csv')
dataset8 = pd.read_csv('Dataset8.csv')
dataset9 = pd.read_csv('Dataset9.csv')
data10 = pd.read_csv('data10.csv')
data11 = pd.read_csv('data11.csv')
data12 = pd.read_csv('data12.csv')
data13 = pd.read_csv('data13.csv')
Moon = pd.read_csv('Moon.csv')
Moon2 = pd.read_csv('Moon2.csv')
xor = pd.read_csv('XOR.csv')

# %%
# sns.scatterplot(x='x1', y='x2', data=data10, hue='y')
# plt.show()

# %%
fig, axes = plt.subplots(4, 4, figsize=(18, 18))

# fig.suptitle('Suptitle')

sns.scatterplot(ax=axes[0, 0], data=dataset1, x='x1', y='x2', hue='y',style = 'y').set(title='dataset1')
sns.scatterplot(ax=axes[0, 1], data=dataset2,  x='x1', y='x2', hue='y',style = 'y').set(title='dataset2')
sns.scatterplot(ax=axes[0, 2], data=dataset3,  x='x1', y='x2', hue='y',style = 'y').set(title='dataset3')
sns.scatterplot(ax=axes[0, 3], data=dataset4,  x='x1', y='x2', hue='y',style = 'y').set(title='dataset4')
sns.scatterplot(ax=axes[1, 0], data=dataset5,  x='x1', y='x2', hue='y',style = 'y').set(title='dataset5')
sns.scatterplot(ax=axes[1, 1], data=dataset6,  x='x1', y='x2', hue='y',style = 'y').set(title='dataset6')
sns.scatterplot(ax=axes[1, 2], data=dataset7,  x='x1', y='x2', hue='y',style = 'y').set(title='dataset7')
sns.scatterplot(ax=axes[1, 3], data=dataset8,  x='x1', y='x2', hue='y',style = 'y').set(title='dataset8')
sns.scatterplot(ax=axes[2, 0], data=dataset9,  x='x1', y='x2', hue='y',style = 'y').set(title='dataset9')
sns.scatterplot(ax=axes[2, 1], data=data10,  x='x1', y='x2', hue='y',style = 'y').set(title='data10')
sns.scatterplot(ax=axes[2, 2], data=data11,  x='x1', y='x2', hue='y',style = 'y').set(title='data11')
sns.scatterplot(ax=axes[2, 3], data=data12,  x='x1', y='x2', hue='y',style = 'y').set(title='data12')
sns.scatterplot(ax=axes[3, 0], data=data13,  x='x1', y='x2', hue='y',style = 'y').set(title='data13')
sns.scatterplot(ax=axes[3, 1], data=Moon,  x='x1', y='x2', hue='y',style = 'y').set(title='Moon')
sns.scatterplot(ax=axes[3, 2], data=Moon2,  x='x1', y='x2', hue='y',style = 'y').set(title='Moon2')
sns.scatterplot(ax=axes[3, 3], data=xor,  x='x1', y='x2', hue='y',style = 'y').set(title='XOR')

plt.show()

# %% [markdown]
# ## Complexity boxplots

# %%
path_csv = os.chdir(root_path+'/Results_Complexity_InstanceLevel')


# Extraemos los nombres de todos los ficheros
total_name_list = []
for filename in os.listdir(path_csv):
    if filename.endswith('.csv'):
        total_name_list.append(filename)


cols_name = ['dataset','Hostility', 'kDN', 'DS', 'DCP', 'TD_U', 'TD_P', 'MV', 'CB', 'CLD',
       'N1', 'N2', 'LSC', 'LSradius', 'H', 'U', 'F1', 'F2', 'F3', 'F4']
data_total = pd.DataFrame(columns=cols_name)

for data_file in total_name_list:
    # print(data_file)
    file = data_file

    file_name = data_file[33:-4]
    data = pd.read_csv(file,index_col=0)
    data['dataset'] = file_name
    data_total = pd.concat([data_total, data], ignore_index=True)

# %%
fig, axes = plt.subplots(3, 3, figsize=(18, 18))

# fig.suptitle('Suptitle')
sns.boxplot(ax=axes[0, 0],data=data_total, x="CLD", y="dataset")
sns.boxplot(ax=axes[0, 1],data=data_total, x="DCP", y="dataset")
sns.boxplot(ax=axes[0, 2],data=data_total, x="F1", y="dataset")
sns.boxplot(ax=axes[1, 0],data=data_total, x="LSC", y="dataset")
sns.boxplot(ax=axes[1, 1],data=data_total, x="N1", y="dataset")
sns.boxplot(ax=axes[1, 2],data=data_total, x="N2", y="dataset")
sns.boxplot(ax=axes[2, 0],data=data_total, x="TD_U", y="dataset")
sns.boxplot(ax=axes[2, 1],data=data_total, x="kDN", y="dataset")
sns.boxplot(ax=axes[2, 2],data=data_total, x="Hostility", y="dataset")
plt.show()
