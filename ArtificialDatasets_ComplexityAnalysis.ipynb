# %% [markdown]
# ## Artificial datasets and complexity at the instance level

# %%
# Load packages
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
root_path = os.getcwd()
os.chdir(root_path+'/datasets')

# %%
# dataset1 = pd.read_csv('Dataset1.csv')
dataset2 = pd.read_csv('Dataset2.csv')
dataset3 = pd.read_csv('Dataset3.csv')
# dataset4 = pd.read_csv('Dataset4.csv')
# dataset5 = pd.read_csv('Dataset5.csv')
dataset6 = pd.read_csv('Dataset6.csv')
dataset7 = pd.read_csv('Dataset7.csv')
dataset8 = pd.read_csv('Dataset8.csv')
# dataset9 = pd.read_csv('Dataset9.csv')
dataset10 = pd.read_csv('Dataset10.csv')
dataset11 = pd.read_csv('Dataset11.csv')
# dataset12 = pd.read_csv('Dataset12.csv')
# dataset13 = pd.read_csv('Dataset13.csv')
dataset14 = pd.read_csv('Dataset14.csv')
# dataset15 = pd.read_csv('Dataset15.csv')
# dataset16 = pd.read_csv('Dataset16.csv')
# Moon = pd.read_csv('Moon.csv')
Moon2 = pd.read_csv('Moon2.csv')
# xor = pd.read_csv('XOR.csv')
dataset17 = pd.read_csv('Dataset17.csv')
dataset18 = pd.read_csv('Dataset18.csv')
dataset19 = pd.read_csv('Dataset19.csv')
dataset20 = pd.read_csv('Dataset20.csv')
dataset21 = pd.read_csv('Dataset21.csv')
dataset22 = pd.read_csv('Dataset22.csv')
dataset23 = pd.read_csv('Dataset23.csv')
dataset24 = pd.read_csv('Dataset24.csv')
dataset25 = pd.read_csv('Dataset25.csv')
dataset26 = pd.read_csv('Dataset26.csv')
dataset27 = pd.read_csv('Dataset27.csv')

# %%
# sns.scatterplot(x='x1', y='x2', data=data10, hue='y')
# plt.show()

# %%
# fig, axes = plt.subplots(5, 4, figsize=(18, 18))
#
# # fig.suptitle('Suptitle')
#
# sns.scatterplot(ax=axes[0, 0], data=dataset1, x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset1')
# sns.scatterplot(ax=axes[0, 1], data=dataset2,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset2')
# sns.scatterplot(ax=axes[0, 2], data=dataset3,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset3')
# sns.scatterplot(ax=axes[0, 3], data=dataset4,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset4')
# sns.scatterplot(ax=axes[1, 0], data=dataset5,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset5')
# sns.scatterplot(ax=axes[1, 1], data=dataset6,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset6')
# sns.scatterplot(ax=axes[1, 2], data=dataset7,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset7')
# sns.scatterplot(ax=axes[1, 3], data=dataset8,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset8')
# sns.scatterplot(ax=axes[2, 0], data=dataset9,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset9')
# sns.scatterplot(ax=axes[2, 1], data=dataset10,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset10')
# sns.scatterplot(ax=axes[2, 2], data=dataset11,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset11')
# sns.scatterplot(ax=axes[2, 3], data=dataset12,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset12')
# sns.scatterplot(ax=axes[3, 0], data=dataset13,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset13')
# sns.scatterplot(ax=axes[3, 1], data=dataset14,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset14')
# sns.scatterplot(ax=axes[3, 2], data=dataset15,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset15')
# sns.scatterplot(ax=axes[3, 3], data=dataset16,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset16')
# sns.scatterplot(ax=axes[4, 0], data=Moon,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='Moon')
# sns.scatterplot(ax=axes[4, 1], data=Moon2,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='Moon2')
# sns.scatterplot(ax=axes[4, 2], data=xor,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='XOR')
#
# plt.show()

# %%
fig, axes = plt.subplots(4, 4, figsize=(18, 18))

# fig.suptitle('Suptitle')

# sns.scatterplot(ax=axes[0, 0], data=dataset1, x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset1')
# sns.scatterplot(ax=axes[0, 0], data=dataset2,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset2')
sns.scatterplot(ax=axes[0, 0], data=dataset3,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset3')
# sns.scatterplot(ax=axes[0, 3], data=dataset4,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset4')
# sns.scatterplot(ax=axes[1, 0], data=dataset5,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset5')
sns.scatterplot(ax=axes[0, 1], data=dataset6,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset6')
sns.scatterplot(ax=axes[0, 2], data=dataset7,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset7')
# sns.scatterplot(ax=axes[1, 0], data=dataset8,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset8')
# sns.scatterplot(ax=axes[2, 0], data=dataset9,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset9')
sns.scatterplot(ax=axes[0, 3], data=dataset10,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset10')
sns.scatterplot(ax=axes[1, 0], data=dataset11,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset11')
# sns.scatterplot(ax=axes[2, 3], data=dataset12,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset12')
# sns.scatterplot(ax=axes[3, 0], data=dataset13,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset13')
sns.scatterplot(ax=axes[1, 1], data=dataset14,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset14')
# sns.scatterplot(ax=axes[3, 2], data=dataset15,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset15')
# sns.scatterplot(ax=axes[3, 3], data=dataset16,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset16')
# sns.scatterplot(ax=axes[4, 0], data=Moon,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='Moon')
sns.scatterplot(ax=axes[1, 2], data=Moon2,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='Moon2')
# sns.scatterplot(ax=axes[4, 2], data=xor,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='XOR')
# sns.scatterplot(ax=axes[2, 1], data=dataset17,  x='x1', y='x2', hue='y',style = 'y', s=6).set(title='dataset17')
# sns.scatterplot(ax=axes[1, 3], data=dataset18,  x='x1', y='x2', hue='y',style = 'y', s=6,palette=["C0", "C1", "k"]).set(title='dataset18')
sns.scatterplot(ax=axes[1, 3], data=dataset19,  x='x1', y='x2', hue='y',style = 'y', s=6,palette=["C0", "C1", "k"]).set(title='dataset19')
sns.scatterplot(ax=axes[2, 0], data=dataset20,  x='x1', y='x2', hue='y',style = 'y', s=6,palette=["C0", "C1", "k",'pink','green','gold']).set(title='dataset20')
sns.scatterplot(ax=axes[2, 1], data=dataset21,  x='x1', y='x2', hue='y',style = 'y', s=6,palette=["C0", "C1", "k"]).set(title='dataset21')
sns.scatterplot(ax=axes[2, 2], data=dataset22,  x='x1', y='x2', hue='y',style = 'y', s=6,palette=["C0", "C1", "k"]).set(title='dataset22')
sns.scatterplot(ax=axes[2, 3], data=dataset23,  x='x1', y='x2', hue='y',style = 'y', s=6,palette=["C0", "C1", "k",'green','gold']).set(title='dataset23')
sns.scatterplot(ax=axes[3, 0], data=dataset24,  x='x1', y='x2', hue='y',style = 'y', s=6,palette=["C0", "C1", "k"]).set(title='dataset24')
sns.scatterplot(ax=axes[3, 1], data=dataset25,  x='x1', y='x2', hue='y',style = 'y', s=6,palette=["C0", "C1", "k"]).set(title='dataset25')
sns.scatterplot(ax=axes[3, 2], data=dataset26,  x='x1', y='x2', hue='y',style = 'y', s=6,palette=["C0", "C1", "k",'green']).set(title='dataset26')
sns.scatterplot(ax=axes[3, 3], data=dataset27,  x='x1', y='x2', hue='y',style = 'y', s=6,palette=["C0", "C1", "k",'green']).set(title='dataset27')

plt.show()

# %% [markdown]
# ## Complexity boxplots

# %%
path_csv = os.chdir(root_path+'/Results_Complexity_InstanceLevel')


# Extraemos los nombres de todos los ficheros
total_name_list = []
for filename in os.listdir(path_csv):
    if filename.endswith('.csv'):
        total_name_list.append(filename)

total_name_list = ['ComplexityMeasures_InstanceLevel_Dataset3.csv',
                   'ComplexityMeasures_InstanceLevel_Dataset6.csv','ComplexityMeasures_InstanceLevel_Dataset7.csv',
                   'ComplexityMeasures_InstanceLevel_Dataset10.csv',
                   'ComplexityMeasures_InstanceLevel_Dataset11.csv','ComplexityMeasures_InstanceLevel_Dataset14.csv',
                   'ComplexityMeasures_InstanceLevel_Moon2.csv',
                   'ComplexityMeasures_InstanceLevel_Dataset19.csv','ComplexityMeasures_InstanceLevel_Dataset20.csv',
                   'ComplexityMeasures_InstanceLevel_Dataset21.csv','ComplexityMeasures_InstanceLevel_Dataset22.csv',
                   'ComplexityMeasures_InstanceLevel_Dataset23.csv','ComplexityMeasures_InstanceLevel_Dataset24.csv',
                   'ComplexityMeasures_InstanceLevel_Dataset25.csv','ComplexityMeasures_InstanceLevel_Dataset26.csv',
                   'ComplexityMeasures_InstanceLevel_Dataset27.csv']

cols_name = ['dataset','Hostility', 'kDN', 'DS', 'DCP', 'TD_U', 'TD_P', 'MV', 'CB', 'CLD',
       'N1', 'N2', 'LSC', 'LSradius', 'H', 'U', 'F1', 'F2', 'F3', 'F4']
data_total = pd.DataFrame(columns=cols_name)

for data_file in total_name_list:
    # print(data_file)
    file = data_file

    file_name = data_file[33:-4]
    data = pd.read_csv(file,index_col=0)
    data['dataset'] = file_name
    data_total = pd.concat([data_total, data], ignore_index=True)

# %%
# order_fixed=['Dataset1','Dataset2','Dataset3','Dataset4','Dataset5','Dataset6','Dataset7','Dataset8','Dataset9',
#        'Dataset10','Dataset11','Dataset12','Dataset13','Dataset14','Dataset15','Dataset16','Moon','Moon2','XOR']
order_fixed=['Dataset3','Dataset6','Dataset7',
       'Dataset10','Dataset11','Dataset14','Dataset19','Dataset20',
             'Dataset21','Dataset22','Dataset23','Dataset24','Dataset25','Dataset26','Dataset27','Moon2']

# %%
fig, axes = plt.subplots(3, 3, figsize=(18, 18))

# fig.suptitle('Suptitle')
sns.boxplot(ax=axes[0, 0],data=data_total, x="CLD", y="dataset", order=order_fixed)
sns.boxplot(ax=axes[0, 1],data=data_total, x="DCP", y="dataset", order=order_fixed)
sns.boxplot(ax=axes[0, 2],data=data_total, x="F1", y="dataset", order=order_fixed)
sns.boxplot(ax=axes[1, 0],data=data_total, x="LSC", y="dataset", order=order_fixed)
sns.boxplot(ax=axes[1, 1],data=data_total, x="N1", y="dataset", order=order_fixed)
sns.boxplot(ax=axes[1, 2],data=data_total, x="N2", y="dataset", order=order_fixed)
sns.boxplot(ax=axes[2, 0],data=data_total, x="TD_U", y="dataset", order=order_fixed)
sns.boxplot(ax=axes[2, 1],data=data_total, x="kDN", y="dataset", order=order_fixed)
sns.boxplot(ax=axes[2, 2],data=data_total, x="Hostility", y="dataset", order=order_fixed)
plt.show()
