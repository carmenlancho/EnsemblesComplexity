# %% [markdown]
# # Dataset characteristics

# %% [markdown]
# In this notebook we present the characteristics of the benchmark datasets in terms of type of target (binary or multiclass), proportion of the positive class, number of features and number of instances.

# %%
import pandas as pd
import os

# %%
os.chdir("..")
root_path = os.getcwd()

# %%
path_csv = os.path.join(root_path, 'datasets')
os.chdir(path_csv)

total_name_list = []
target_type_list = []
class1_proportion_list = []
num_rows_list = []
num_columns_list = []

multiclass_name_list = []
class_list = []
class_proportion_list = []

for filename in os.listdir(path_csv):
    if filename.endswith('.csv'):
        df = pd.read_csv(filename)
        target = df['y']
        
        unique_classes = target.nunique()
        if unique_classes == 2:
            target_type = 'binary'
            class1_proportion = target.value_counts(normalize=True).get(1, 0)
        else:
            target_type = 'multiclass'
            class1_proportion = None
            class_proportions = target.value_counts(normalize=True)
            for class_value, proportion in class_proportions.items():
                multiclass_name_list.append(filename)
                class_list.append(class_value)
                class_proportion_list.append(proportion)

        total_name_list.append(filename)
        target_type_list.append(target_type)
        class1_proportion_list.append(class1_proportion)
        num_rows_list.append(df.shape[0])      
        num_columns_list.append(df.shape[1])   

general_df = pd.DataFrame({
    'dataset_name': total_name_list,
    'target_type': target_type_list,
    'class1_proportion': class1_proportion_list,
    'num_rows': num_rows_list,
    'num_columns': num_columns_list
})

multiclass_df = pd.DataFrame({
    'dataset_name': multiclass_name_list,
    'class': class_list,
    'class_proportion': class_proportion_list
})

# %%
general_df
# Out:
#                                dataset_name target_type  class1_proportion  \
# 0                 teaching_assistant_MH.csv     binario           0.509804
# 1                             cleveland.csv  multiclase                NaN
# 2                      contraceptive_NL.csv     binario           0.346154
# 3   hill_valley_without_noise_traintest.csv     binario           0.504950
# 4                                glass0.csv     binario           0.327103
# 5                               saheart.csv     binario           0.346320
# 6                              breast-w.csv     binario           0.344778
# 7                      contraceptive_LS.csv     binario           0.605450
# 8                                yeast1.csv     binario           0.289084
# 9                                  ilpd.csv     binario           0.284974
# 10                              phoneme.csv     binario           0.293486
# 11                         mammographic.csv     binario           0.485542
# 12                     contraceptive_NS.csv     binario           0.448246
# 13                                 bupa.csv     binario           0.579710
# 14                       Yeast_CYTvsNUC.csv     binario           0.480942
# 15                                 ring.csv     binario           0.504865
# 16                              titanic.csv     binario           0.381971
# 17                                musk1.csv     binario           0.434874
# 18                          spectfheart.csv     binario           0.794007
# 19                       arrhythmia_cfs.csv     binario           0.457965
# 20                     vertebral_column.csv     binario           0.677419
# 21                                profb.csv     binario           0.333333
# 22                                sonar.csv     binario           0.533654
# 23                      liver-disorders.csv     binario           0.379310
# 24                   steel-plates-fault.csv     binario           0.346728
# 25                             credit-g.csv     binario           0.700000
# 26                               glass1.csv     binario           0.355140
# 27                              segment.csv  multiclase                NaN
# 28                         breastcancer.csv     binario           0.372583
# 29                             diabetes.csv     binario           0.348958
# 30                 diabetic_retinopathy.csv     binario           0.530843
# 31               analcatdata_authorship.csv  multiclase                NaN
# 32                  WineQualityRed_5vs6.csv     binario           0.483700
# 33                teaching_assistant_LM.csv     binario           0.505051
# 34                           ionosphere.csv     binario           0.358974
# 35                                bands.csv     binario           0.369863
# 36                                 wdbc.csv     binario           0.372583
# 37                              sylvine.csv     binario           0.500000
# 38                teaching_assistant_LH.csv     binario           0.514851
# 39                             vehicle2.csv     binario           0.257683
# 40                                 pima.csv     binario           0.348958
# 41                             spambase.csv     binario           0.394170
# 42                        fri_c0_250_50.csv     binario           0.532000
# 43                           parkinsons.csv     binario           0.753846
# 44                              bodyfat.csv     binario           0.492063
# 45              banknote_authentication.csv     binario           0.444606
# 46                          chatfield_4.csv     binario           0.604255
#
#     num_rows  num_columns
# 0        102            4
# 1        303           14
# 2        962           10
# 3       1212          101
# 4        214           10
# 5        462           10
# 6        699           10
# 7        844           10
# 8       1484            9
# 9        579           11
# 10      5404            6
# 11       830            6
# 12      1140           10
# 13       345            7
# 14       892            9
# 15      7400           21
# 16      1309           10
# 17       476          167
# 18       267           45
# 19       452           38
# 20       310            7
# 21       672           10
# 22       208           61
# 23       145            6
# 24      1941           34
# 25      1000           20
# 26       214           10
# 27      2310           20
# 28       569           31
# 29       768            9
# 30      1151           20
# 31       841           71
# 32      1319           12
# 33        99            4
# 34       351           34
# 35       365           20
# 36       569           31
# 37      5124           21
# 38       101            4
# 39       846           19
# 40       768            9
# 41      4597           58
# 42       250           51
# 43       195           23
# 44       252           15
# 45      1372            5
# 46       235           13

# %% [markdown]
# We are finally not using multiclass dataset since the sampling needs some specific modifications to ensure that every class is correctly represented. Besides, we only have 3 multiclass datasets and we're developing the method for Boosting only for binary targets. Therefore, we delete cleveland, segment and analcatdata_authorship datasets.

# %%
multiclass_df
# Out:
#                   dataset_name  class  class_proportion
# 0                cleveland.csv      0          0.541254
# 1                cleveland.csv      1          0.181518
# 2                cleveland.csv      2          0.118812
# 3                cleveland.csv      3          0.115512
# 4                cleveland.csv      4          0.042904
# 5                  segment.csv      5          0.142857
# 6                  segment.csv      2          0.142857
# 7                  segment.csv      6          0.142857
# 8                  segment.csv      0          0.142857
# 9                  segment.csv      3          0.142857
# 10                 segment.csv      4          0.142857
# 11                 segment.csv      1          0.142857
# 12  analcatdata_authorship.csv      0          0.376932
# 13  analcatdata_authorship.csv      1          0.351962
# 14  analcatdata_authorship.csv      3          0.205707
# 15  analcatdata_authorship.csv      2          0.065398

# %% [markdown]
# We delete those datasets:

# %%
path_csv = os.path.join(root_path, 'datasets')
os.chdir(path_csv)

total_name_list = []
target_type_list = []
class1_proportion_list = []
num_rows_list = []
num_columns_list = []

multiclass_name_list = []
class_list = []
class_proportion_list = []

for filename in os.listdir(path_csv):
    if filename.endswith('.csv'):
        df = pd.read_csv(filename)
        target = df['y']
        
        unique_classes = target.nunique()
        if unique_classes == 2:
            target_type = 'binary'
            class1_proportion = target.value_counts(normalize=True).get(1, 0)
        else:
            target_type = 'multiclass'
            class1_proportion = None

        total_name_list.append(filename)
        target_type_list.append(target_type)
        class1_proportion_list.append(class1_proportion)
        num_rows_list.append(df.shape[0])      
        num_columns_list.append(df.shape[1])   

general_df_binary = pd.DataFrame({
    'dataset_name': total_name_list,
    'target_type': target_type_list,
    'class1_proportion': class1_proportion_list,
    'num_rows': num_rows_list,
    'num_columns': num_columns_list
})

# %%
general_df_binary
# Out:
#                                dataset_name target_type  class1_proportion  \
# 0                 teaching_assistant_MH.csv      binary           0.509804
# 1                      contraceptive_NL.csv      binary           0.346154
# 2   hill_valley_without_noise_traintest.csv      binary           0.504950
# 3                                glass0.csv      binary           0.327103
# 4                               saheart.csv      binary           0.346320
# 5                              breast-w.csv      binary           0.344778
# 6                      contraceptive_LS.csv      binary           0.605450
# 7                                yeast1.csv      binary           0.289084
# 8                                  ilpd.csv      binary           0.284974
# 9                               phoneme.csv      binary           0.293486
# 10                         mammographic.csv      binary           0.485542
# 11                     contraceptive_NS.csv      binary           0.448246
# 12                                 bupa.csv      binary           0.579710
# 13                       Yeast_CYTvsNUC.csv      binary           0.480942
# 14                                 ring.csv      binary           0.504865
# 15                              titanic.csv      binary           0.381971
# 16                                musk1.csv      binary           0.434874
# 17                          spectfheart.csv      binary           0.794007
# 18                       arrhythmia_cfs.csv      binary           0.457965
# 19                     vertebral_column.csv      binary           0.677419
# 20                                profb.csv      binary           0.333333
# 21                                sonar.csv      binary           0.533654
# 22                      liver-disorders.csv      binary           0.379310
# 23                   steel-plates-fault.csv      binary           0.346728
# 24                             credit-g.csv      binary           0.700000
# 25                               glass1.csv      binary           0.355140
# 26                         breastcancer.csv      binary           0.372583
# 27                             diabetes.csv      binary           0.348958
# 28                 diabetic_retinopathy.csv      binary           0.530843
# 29                  WineQualityRed_5vs6.csv      binary           0.483700
# 30                teaching_assistant_LM.csv      binary           0.505051
# 31                           ionosphere.csv      binary           0.358974
# 32                                bands.csv      binary           0.369863
# 33                                 wdbc.csv      binary           0.372583
# 34                              sylvine.csv      binary           0.500000
# 35                teaching_assistant_LH.csv      binary           0.514851
# 36                             vehicle2.csv      binary           0.257683
# 37                                 pima.csv      binary           0.348958
# 38                             spambase.csv      binary           0.394170
# 39                        fri_c0_250_50.csv      binary           0.532000
# 40                           parkinsons.csv      binary           0.753846
# 41                              bodyfat.csv      binary           0.492063
# 42              banknote_authentication.csv      binary           0.444606
# 43                          chatfield_4.csv      binary           0.604255
#
#     num_rows  num_columns
# 0        102            4
# 1        962           10
# 2       1212          101
# 3        214           10
# 4        462           10
# 5        699           10
# 6        844           10
# 7       1484            9
# 8        579           11
# 9       5404            6
# 10       830            6
# 11      1140           10
# 12       345            7
# 13       892            9
# 14      7400           21
# 15      1309           10
# 16       476          167
# 17       267           45
# 18       452           38
# 19       310            7
# 20       672           10
# 21       208           61
# 22       145            6
# 23      1941           34
# 24      1000           20
# 25       214           10
# 26       569           31
# 27       768            9
# 28      1151           20
# 29      1319           12
# 30        99            4
# 31       351           34
# 32       365           20
# 33       569           31
# 34      5124           21
# 35       101            4
# 36       846           19
# 37       768            9
# 38      4597           58
# 39       250           51
# 40       195           23
# 41       252           15
# 42      1372            5
# 43       235           13
